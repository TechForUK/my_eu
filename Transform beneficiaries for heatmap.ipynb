# %%
# import arrow

# %% [markdown]
# # Load

# %%
beneficiaries = pd.read_csv('data/esif_2014_2020_beneficiaries_lat_lon.csv')

# %%
beneficiaries.head()
# Out:
#    Unnamed: 0                                       Bénéficiaire  \
# 0           0            Building Research Establishment Limited
# 1           1                                           GCGP LEP
# 2           2  Greater Cambridge and Greater Peterborough Loc...
# 3           3                    Satellite Applications Catapult
# 4           4                           Hastings Borough Council
#
#                                        Nom du projet Fonds  \
# 0        Hertfordshire Low Carbon Innovation Network  ERDF
# 1  Promoting Growth in Greater Cambridge Greater ...  ERDF
# 2  Promoting Growth in Greater Cambridge Greater ...   ESF
# 3                Westcott Business Incubation Centre  ERDF
# 4  CHART (Connecting Hastings and Rother Together...  ERDF
#
#                  Unnamed: 3  \
# 0                         4
# 1                         9
# 2  3 - Technical Assistance
# 3                         1
# 4                         8
#
#                                     Résumé du projet Date de commencement  \
# 0  Strategic Fit and Value for Money requirements...           2016-05-01
# 1  The project will provide local facilitation re...           2015-10-01
# 2  The project will provide local facilitation to...           2016-01-01
# 3  Incubation centre for collaboration & business...           2017-10-01
# 4  Promoting self-employment, small business star...           2016-10-26
#
#   Date de fin Investissement FEDER/FSE £m Coût total du projet £m  \
# 0  2019-02-28                      630000                 1260000
# 1  2018-12-31                      373677                  747356
# 2  2020-10-31                      115763                  231531
# 3  2020-12-31                      500000                 1000000
# 4  2022-12-31                     2073538                 4147076
#
#    % du projet cofinancé par l’UE Localisation (code postal)  \
# 0                             0.5                   WD25 9XX
# 1                             0.5                   PE28 4WX
# 2                             0.5                   PE28 4WX
# 3                             0.5                   OX11 0QR
# 4                             0.5                   TN34 3UY
#
#        Zone de partenariat économique local     Pays  \
# 0                             Hertfordshire  England
# 1  Greater Cambridge & Greater Peterborough  England
# 2  Greater Cambridge & Greater Peterborough  England
# 3                       Bucks Thames Valley  England
# 4                                South East  England
#
#    Type et axe du soutien (catégorie d’intervention) postcode      id  \
# 0  068 Energy efficiency and demonstration projec...  WD259XX   72908
# 1                  123 Information and communication  PE284WX  573113
# 2                  123 Information and communication  PE284WX  573113
# 3  062 Technology transfer and university-enterpr...  OX110QR  614913
# 4  097 Community led local development initiative...  TN343UY  182439
#
#     latitude  longitude
# 0  51.700174  -0.372749
# 1  52.379569  -0.223194
# 2  52.379569  -0.223194
# 3  51.577203  -1.309172
# 4  50.855355   0.583707

# %%
beneficiaries = beneficiaries.rename(columns={
    'Coût total du projet £m': 'project_cost', 
    'Investissement FEDER/FSE £m': 'eu_investment',
    '% du projet cofinancé par l’UE': 'prop_eu_financed',
    'latitude': 'lat', 
    'longitude': 'lng',
    'Bénéficiaire': 'beneficiary',
    'Nom du projet': 'project',
    'Zone de partenariat économique local': 'economic_zone',
    'Résumé du projet': 'summary',
    'Date de commencement': 'start_date'
})

# %%
beneficiaries['start_date'] = pd.to_datetime(beneficiaries.start_date, format='%Y-%m-%d')

# %%
beneficiaries[['project_cost', 'eu_investment']] = beneficiaries[['project_cost', 'eu_investment']].apply(
    lambda s: s.str.strip().str.replace(',', '').str.replace(r'(\.)[\d|\.]{3,}\b', '')
).astype(float)

# %%
beneficiaries['project'] = beneficiaries.project.str.replace('\n', '').str.replace("''", '')

# %%
beneficiaries[['beneficiary', 'project', 'summary', 'start_date', 'project_cost', 'eu_investment', 'prop_eu_financed', 'lat', 'lng']].head()
# Out:
#                                          beneficiary  \
# 0            Building Research Establishment Limited
# 1                                           GCGP LEP
# 2  Greater Cambridge and Greater Peterborough Loc...
# 3                    Satellite Applications Catapult
# 4                           Hastings Borough Council
#
#                                              project  \
# 0        Hertfordshire Low Carbon Innovation Network
# 1  Promoting Growth in Greater Cambridge Greater ...
# 2  Promoting Growth in Greater Cambridge Greater ...
# 3                Westcott Business Incubation Centre
# 4  CHART (Connecting Hastings and Rother Together...
#
#                                              summary start_date  project_cost  \
# 0  Strategic Fit and Value for Money requirements... 2016-05-01     1260000.0
# 1  The project will provide local facilitation re... 2015-10-01      747356.0
# 2  The project will provide local facilitation to... 2016-01-01      231531.0
# 3  Incubation centre for collaboration & business... 2017-10-01     1000000.0
# 4  Promoting self-employment, small business star... 2016-10-26     4147076.0
#
#    eu_investment  prop_eu_financed        lat       lng
# 0       630000.0               0.5  51.700174 -0.372749
# 1       373677.0               0.5  52.379569 -0.223194
# 2       115763.0               0.5  52.379569 -0.223194
# 3       500000.0               0.5  51.577203 -1.309172
# 4      2073538.0               0.5  50.855355  0.583707

# %% [markdown]
# # Save

# %%
beneficiaries.to_pickle('data/beneficiaries.pkl')
